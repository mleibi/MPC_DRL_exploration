# %% [markdown]
# # Swing up in dm_control

# %%
# imports
import numpy as np

from dm_control import suite
from dm_control import viewer
from dm_env import StepType

from stable_baselines3 import PPO, SAC

import time
from statistics import mean, stdev

import gym
from gym.spaces import Box

# %%
class DMControlWrapper(gym.Env):
    def __init__(self, domain_name, task_name):
        self.env = suite.load(domain_name=domain_name, task_name=task_name)
        obs_shape = sum([value.shape[0] for value in self.env.observation_spec().values()])
        self.observation_space = Box(low=-np.inf, high=np.inf, shape=(obs_shape,), dtype=np.float32)
        self.action_space = Box(low=self.env.action_spec().minimum[0], high=self.env.action_spec().maximum[0], shape=self.env.action_spec().shape, dtype=np.float32)

    def reset(self):
        time_step = self.env.reset()
        return np.array(self.get_obs(time_step))

    def step(self, action):
        time_step = self.env.step(action)
        return np.array(self.get_obs(time_step)), time_step.reward, time_step.last(), {}

    def get_obs(self, time_step):
        return np.concatenate([value for value in time_step.observation.values()])
    
    def action_spec(self):
        return self.env.action_spec()

# %% [markdown]
# ## PPO

# %%
env = DMControlWrapper("cartpole", "swingup")
PPO_model = PPO("MlpPolicy", env, verbose=1)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
PPO_model.learn(total_timesteps=500000)
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 27.5     |
# | time/              |          |
# |    fps             | 4174     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 110          |
# | time/                   |              |
# |    fps                  | 2756         |
# |    iterations           | 2            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0045975293 |
# |    clip_fraction        | 0.0371       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.147        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0704       |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00321     |
# |    std                  | 0.985        |
# |    value_loss           | 0.225        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 92.6         |
# | time/                   |              |
# |    fps                  | 2479         |
# |    iterations           | 3            |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0032320255 |
# |    clip_fraction        | 0.013        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.13         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.734        |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00276     |
# |    std                  | 0.984        |
# |    value_loss           | 6.91         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 81.7         |
# | time/                   |              |
# |    fps                  | 2369         |
# |    iterations           | 4            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0037896354 |
# |    clip_fraction        | 0.0152       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.715        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.173        |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00176     |
# |    std                  | 0.973        |
# |    value_loss           | 0.841        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 83           |
# | time/                   |              |
# |    fps                  | 2295         |
# |    iterations           | 5            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0062907445 |
# |    clip_fraction        | 0.049        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.875        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0426       |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.0057      |
# |    std                  | 0.941        |
# |    value_loss           | 0.196        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 99           |
# | time/                   |              |
# |    fps                  | 2259         |
# |    iterations           | 6            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0033339544 |
# |    clip_fraction        | 0.0101       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.855        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.352        |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00174     |
# |    std                  | 0.935        |
# |    value_loss           | 1.69         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 113         |
# | time/                   |             |
# |    fps                  | 2239        |
# |    iterations           | 7           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.006095796 |
# |    clip_fraction        | 0.0376      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.859       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.55        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00451    |
# |    std                  | 0.94        |
# |    value_loss           | 5.24        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 124          |
# | time/                   |              |
# |    fps                  | 2224         |
# |    iterations           | 8            |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0033632535 |
# |    clip_fraction        | 0.0237       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.914        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.05         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00298     |
# |    std                  | 0.939        |
# |    value_loss           | 3.63         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 132          |
# | time/                   |              |
# |    fps                  | 2213         |
# |    iterations           | 9            |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0023254377 |
# |    clip_fraction        | 0.00757      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.914        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.67         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.000894    |
# |    std                  | 0.937        |
# |    value_loss           | 4.17         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 141          |
# | time/                   |              |
# |    fps                  | 2204         |
# |    iterations           | 10           |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0021885796 |
# |    clip_fraction        | 0.00654      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.884        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.6          |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00104     |
# |    std                  | 0.931        |
# |    value_loss           | 3.96         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 151         |
# | time/                   |             |
# |    fps                  | 2196        |
# |    iterations           | 11          |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.004219565 |
# |    clip_fraction        | 0.0375      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.94        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.879       |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00438    |
# |    std                  | 0.931       |
# |    value_loss           | 2.36        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 158          |
# | time/                   |              |
# |    fps                  | 2190         |
# |    iterations           | 12           |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0034732274 |
# |    clip_fraction        | 0.0129       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.937        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.837        |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00208     |
# |    std                  | 0.928        |
# |    value_loss           | 5.11         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 168         |
# | time/                   |             |
# |    fps                  | 2185        |
# |    iterations           | 13          |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.003739715 |
# |    clip_fraction        | 0.0252      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.924       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.583       |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00201    |
# |    std                  | 0.926       |
# |    value_loss           | 4.37        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 172          |
# | time/                   |              |
# |    fps                  | 2181         |
# |    iterations           | 14           |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0038719524 |
# |    clip_fraction        | 0.044        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.958        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.316        |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00679     |
# |    std                  | 0.919        |
# |    value_loss           | 2.89         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 176          |
# | time/                   |              |
# |    fps                  | 2177         |
# |    iterations           | 15           |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0044487054 |
# |    clip_fraction        | 0.0134       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0.892        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.02         |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00179     |
# |    std                  | 0.907        |
# |    value_loss           | 7.42         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 179         |
# | time/                   |             |
# |    fps                  | 2173        |
# |    iterations           | 16          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.001962656 |
# |    clip_fraction        | 0.0113      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.939       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.676       |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.000484   |
# |    std                  | 0.893       |
# |    value_loss           | 2.69        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 181          |
# | time/                   |              |
# |    fps                  | 2171         |
# |    iterations           | 17           |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0018231624 |
# |    clip_fraction        | 0.0192       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 0.903        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.45         |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00212     |
# |    std                  | 0.904        |
# |    value_loss           | 4.74         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 187          |
# | time/                   |              |
# |    fps                  | 2168         |
# |    iterations           | 18           |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0037526838 |
# |    clip_fraction        | 0.0294       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 0.914        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.57         |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00307     |
# |    std                  | 0.906        |
# |    value_loss           | 4.42         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 189         |
# | time/                   |             |
# |    fps                  | 2166        |
# |    iterations           | 19          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.003415049 |
# |    clip_fraction        | 0.0162      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.934       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.51        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00175    |
# |    std                  | 0.892       |
# |    value_loss           | 4.69        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 193          |
# | time/                   |              |
# |    fps                  | 2164         |
# |    iterations           | 20           |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0031856564 |
# |    clip_fraction        | 0.0219       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 0.914        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.03         |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.000894    |
# |    std                  | 0.893        |
# |    value_loss           | 5.34         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 199          |
# | time/                   |              |
# |    fps                  | 2162         |
# |    iterations           | 21           |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0046330253 |
# |    clip_fraction        | 0.0333       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 0.931        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.418        |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00284     |
# |    std                  | 0.89         |
# |    value_loss           | 2.65         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 203          |
# | time/                   |              |
# |    fps                  | 2160         |
# |    iterations           | 22           |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0033092208 |
# |    clip_fraction        | 0.0237       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 0.866        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.26         |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00347     |
# |    std                  | 0.882        |
# |    value_loss           | 8.74         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 207          |
# | time/                   |              |
# |    fps                  | 2159         |
# |    iterations           | 23           |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0038137706 |
# |    clip_fraction        | 0.0185       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.29        |
# |    explained_variance   | 0.954        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.595        |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.000813    |
# |    std                  | 0.88         |
# |    value_loss           | 3.83         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 212         |
# | time/                   |             |
# |    fps                  | 2158        |
# |    iterations           | 24          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.005193762 |
# |    clip_fraction        | 0.0454      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.944       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.444       |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00438    |
# |    std                  | 0.884       |
# |    value_loss           | 3.46        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 214          |
# | time/                   |              |
# |    fps                  | 2157         |
# |    iterations           | 25           |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0036057453 |
# |    clip_fraction        | 0.0297       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.29        |
# |    explained_variance   | 0.934        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.27         |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00284     |
# |    std                  | 0.873        |
# |    value_loss           | 6.54         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 218          |
# | time/                   |              |
# |    fps                  | 2156         |
# |    iterations           | 26           |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0055428217 |
# |    clip_fraction        | 0.0405       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.28        |
# |    explained_variance   | 0.87         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.964        |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.00222     |
# |    std                  | 0.858        |
# |    value_loss           | 6.26         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 221         |
# | time/                   |             |
# |    fps                  | 2155        |
# |    iterations           | 27          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.004171418 |
# |    clip_fraction        | 0.0297      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | 0.929       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.508       |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0033     |
# |    std                  | 0.839       |
# |    value_loss           | 3.32        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 224        |
# | time/                   |            |
# |    fps                  | 2155       |
# |    iterations           | 28         |
# |    time_elapsed         | 26         |
# |    total_timesteps      | 57344      |
# | train/                  |            |
# |    approx_kl            | 0.00403999 |
# |    clip_fraction        | 0.017      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.24      |
# |    explained_variance   | 0.801      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.57       |
# |    n_updates            | 270        |
# |    policy_gradient_loss | -0.00336   |
# |    std                  | 0.833      |
# |    value_loss           | 5.74       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 227          |
# | time/                   |              |
# |    fps                  | 2154         |
# |    iterations           | 29           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0045377654 |
# |    clip_fraction        | 0.044        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.24        |
# |    explained_variance   | 0.891        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.907        |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.00466     |
# |    std                  | 0.84         |
# |    value_loss           | 5.37         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 229          |
# | time/                   |              |
# |    fps                  | 2153         |
# |    iterations           | 30           |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0039981157 |
# |    clip_fraction        | 0.0263       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.25        |
# |    explained_variance   | 0.849        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.439        |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00175     |
# |    std                  | 0.846        |
# |    value_loss           | 5.24         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 232        |
# | time/                   |            |
# |    fps                  | 2152       |
# |    iterations           | 31         |
# |    time_elapsed         | 29         |
# |    total_timesteps      | 63488      |
# | train/                  |            |
# |    approx_kl            | 0.00198374 |
# |    clip_fraction        | 0.0194     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.25      |
# |    explained_variance   | 0.891      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.294      |
# |    n_updates            | 300        |
# |    policy_gradient_loss | -0.000176  |
# |    std                  | 0.839      |
# |    value_loss           | 5.03       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 234         |
# | time/                   |             |
# |    fps                  | 2151        |
# |    iterations           | 32          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.007150924 |
# |    clip_fraction        | 0.0798      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.24       |
# |    explained_variance   | 0.908       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.76        |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0069     |
# |    std                  | 0.831       |
# |    value_loss           | 5.08        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 237         |
# | time/                   |             |
# |    fps                  | 2150        |
# |    iterations           | 33          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.007240945 |
# |    clip_fraction        | 0.0627      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | 0.931       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.439       |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00588    |
# |    std                  | 0.832       |
# |    value_loss           | 2.99        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 240         |
# | time/                   |             |
# |    fps                  | 2150        |
# |    iterations           | 34          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.008800248 |
# |    clip_fraction        | 0.0649      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | 0.866       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.1         |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.00423    |
# |    std                  | 0.827       |
# |    value_loss           | 6.42        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 243         |
# | time/                   |             |
# |    fps                  | 2150        |
# |    iterations           | 35          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.006315658 |
# |    clip_fraction        | 0.0552      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.22       |
# |    explained_variance   | 0.937       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.1         |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00429    |
# |    std                  | 0.821       |
# |    value_loss           | 4.77        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 245          |
# | time/                   |              |
# |    fps                  | 2149         |
# |    iterations           | 36           |
# |    time_elapsed         | 34           |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0049777348 |
# |    clip_fraction        | 0.0536       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.23        |
# |    explained_variance   | 0.917        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.366        |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.00273     |
# |    std                  | 0.831        |
# |    value_loss           | 3.58         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 247         |
# | time/                   |             |
# |    fps                  | 2149        |
# |    iterations           | 37          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.006629856 |
# |    clip_fraction        | 0.0479      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.24       |
# |    explained_variance   | 0.765       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.3        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00139    |
# |    std                  | 0.84        |
# |    value_loss           | 11          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 249          |
# | time/                   |              |
# |    fps                  | 2149         |
# |    iterations           | 38           |
# |    time_elapsed         | 36           |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0049827467 |
# |    clip_fraction        | 0.036        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.24        |
# |    explained_variance   | 0.847        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.34         |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.000662    |
# |    std                  | 0.84         |
# |    value_loss           | 7.61         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 250         |
# | time/                   |             |
# |    fps                  | 2148        |
# |    iterations           | 39          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.004821935 |
# |    clip_fraction        | 0.0375      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.24       |
# |    explained_variance   | 0.835       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.07        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00147    |
# |    std                  | 0.828       |
# |    value_loss           | 4.32        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 252          |
# | time/                   |              |
# |    fps                  | 2148         |
# |    iterations           | 40           |
# |    time_elapsed         | 38           |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0065168785 |
# |    clip_fraction        | 0.0415       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.22        |
# |    explained_variance   | 0.825        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.799        |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.00146     |
# |    std                  | 0.822        |
# |    value_loss           | 6.89         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 254          |
# | time/                   |              |
# |    fps                  | 2148         |
# |    iterations           | 41           |
# |    time_elapsed         | 39           |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0061198645 |
# |    clip_fraction        | 0.0428       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.22        |
# |    explained_variance   | 0.847        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.1          |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.000912    |
# |    std                  | 0.824        |
# |    value_loss           | 6.85         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 257          |
# | time/                   |              |
# |    fps                  | 2147         |
# |    iterations           | 42           |
# |    time_elapsed         | 40           |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0060058134 |
# |    clip_fraction        | 0.0584       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.22        |
# |    explained_variance   | 0.912        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.78         |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00334     |
# |    std                  | 0.816        |
# |    value_loss           | 6.49         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 260          |
# | time/                   |              |
# |    fps                  | 2147         |
# |    iterations           | 43           |
# |    time_elapsed         | 41           |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0029458606 |
# |    clip_fraction        | 0.0596       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.21        |
# |    explained_variance   | 0.91         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.79         |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.00279     |
# |    std                  | 0.811        |
# |    value_loss           | 5.48         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 262          |
# | time/                   |              |
# |    fps                  | 2147         |
# |    iterations           | 44           |
# |    time_elapsed         | 41           |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0064519877 |
# |    clip_fraction        | 0.0557       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.2         |
# |    explained_variance   | 0.897        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.66         |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.0036      |
# |    std                  | 0.8          |
# |    value_loss           | 5.56         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 266          |
# | time/                   |              |
# |    fps                  | 2147         |
# |    iterations           | 45           |
# |    time_elapsed         | 42           |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0026022142 |
# |    clip_fraction        | 0.0334       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.19        |
# |    explained_variance   | 0.872        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.08         |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.00105     |
# |    std                  | 0.797        |
# |    value_loss           | 9.42         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 267          |
# | time/                   |              |
# |    fps                  | 2146         |
# |    iterations           | 46           |
# |    time_elapsed         | 43           |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0067676925 |
# |    clip_fraction        | 0.0689       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.18        |
# |    explained_variance   | 0.93         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.703        |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.00752     |
# |    std                  | 0.777        |
# |    value_loss           | 4.19         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 269          |
# | time/                   |              |
# |    fps                  | 2146         |
# |    iterations           | 47           |
# |    time_elapsed         | 44           |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0032104452 |
# |    clip_fraction        | 0.0336       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.17        |
# |    explained_variance   | 0.765        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.708        |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00105     |
# |    std                  | 0.78         |
# |    value_loss           | 9.61         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 270          |
# | time/                   |              |
# |    fps                  | 2146         |
# |    iterations           | 48           |
# |    time_elapsed         | 45           |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0061871354 |
# |    clip_fraction        | 0.0574       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.17        |
# |    explained_variance   | 0.877        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.936        |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00287     |
# |    std                  | 0.781        |
# |    value_loss           | 4.7          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 272         |
# | time/                   |             |
# |    fps                  | 2146        |
# |    iterations           | 49          |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.006440292 |
# |    clip_fraction        | 0.0872      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.17       |
# |    explained_variance   | 0.934       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.634       |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00893    |
# |    std                  | 0.776       |
# |    value_loss           | 3.24        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 278         |
# | time/                   |             |
# |    fps                  | 2145        |
# |    iterations           | 50          |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.010664282 |
# |    clip_fraction        | 0.0637      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.17       |
# |    explained_variance   | 0.847       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.348       |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.00756    |
# |    std                  | 0.778       |
# |    value_loss           | 4.75        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 282          |
# | time/                   |              |
# |    fps                  | 2145         |
# |    iterations           | 51           |
# |    time_elapsed         | 48           |
# |    total_timesteps      | 104448       |
# | train/                  |              |
# |    approx_kl            | 0.0073119253 |
# |    clip_fraction        | 0.0706       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.17        |
# |    explained_variance   | 0.91         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.89         |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.00628     |
# |    std                  | 0.776        |
# |    value_loss           | 5.36         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 288         |
# | time/                   |             |
# |    fps                  | 2145        |
# |    iterations           | 52          |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.005922579 |
# |    clip_fraction        | 0.0743      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.15       |
# |    explained_variance   | 0.89        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.855       |
# |    n_updates            | 510         |
# ...
# |    n_updates            | 2270        |
# |    policy_gradient_loss | -0.00127    |
# |    std                  | 0.415       |
# |    value_loss           | 46.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 502         |
# | time/                   |             |
# |    fps                  | 2135        |
# |    iterations           | 229         |
# |    time_elapsed         | 219         |
# |    total_timesteps      | 468992      |
# | train/                  |             |
# |    approx_kl            | 0.008360064 |
# |    clip_fraction        | 0.0875      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.531      |
# |    explained_variance   | 0.784       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.6        |
# |    n_updates            | 2280        |
# |    policy_gradient_loss | -0.000488   |
# |    std                  | 0.408       |
# |    value_loss           | 43.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 501         |
# | time/                   |             |
# |    fps                  | 2135        |
# |    iterations           | 230         |
# |    time_elapsed         | 220         |
# |    total_timesteps      | 471040      |
# | train/                  |             |
# |    approx_kl            | 0.004651334 |
# |    clip_fraction        | 0.0845      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.518      |
# |    explained_variance   | 0.844       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.45        |
# |    n_updates            | 2290        |
# |    policy_gradient_loss | -0.000575   |
# |    std                  | 0.404       |
# |    value_loss           | 44.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 504          |
# | time/                   |              |
# |    fps                  | 2135         |
# |    iterations           | 231          |
# |    time_elapsed         | 221          |
# |    total_timesteps      | 473088       |
# | train/                  |              |
# |    approx_kl            | 0.0055711884 |
# |    clip_fraction        | 0.05         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.507       |
# |    explained_variance   | 0.856        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 18.3         |
# |    n_updates            | 2300         |
# |    policy_gradient_loss | -0.000701    |
# |    std                  | 0.4          |
# |    value_loss           | 53.3         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 505         |
# | time/                   |             |
# |    fps                  | 2135        |
# |    iterations           | 232         |
# |    time_elapsed         | 222         |
# |    total_timesteps      | 475136      |
# | train/                  |             |
# |    approx_kl            | 0.012973623 |
# |    clip_fraction        | 0.097       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.498      |
# |    explained_variance   | 0.915       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.27        |
# |    n_updates            | 2310        |
# |    policy_gradient_loss | -0.00337    |
# |    std                  | 0.397       |
# |    value_loss           | 24          |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 509        |
# | time/                   |            |
# |    fps                  | 2135       |
# |    iterations           | 233        |
# |    time_elapsed         | 223        |
# |    total_timesteps      | 477184     |
# | train/                  |            |
# |    approx_kl            | 0.00375145 |
# |    clip_fraction        | 0.0467     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.495     |
# |    explained_variance   | 0.919      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 12.7       |
# |    n_updates            | 2320       |
# |    policy_gradient_loss | -0.00066   |
# |    std                  | 0.397      |
# |    value_loss           | 27.6       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 517         |
# | time/                   |             |
# |    fps                  | 2135        |
# |    iterations           | 234         |
# |    time_elapsed         | 224         |
# |    total_timesteps      | 479232      |
# | train/                  |             |
# |    approx_kl            | 0.006864924 |
# |    clip_fraction        | 0.0832      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.492      |
# |    explained_variance   | 0.896       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21.4        |
# |    n_updates            | 2330        |
# |    policy_gradient_loss | -0.00385    |
# |    std                  | 0.394       |
# |    value_loss           | 37.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 525         |
# | time/                   |             |
# |    fps                  | 2135        |
# |    iterations           | 235         |
# |    time_elapsed         | 225         |
# |    total_timesteps      | 481280      |
# | train/                  |             |
# |    approx_kl            | 0.008874206 |
# |    clip_fraction        | 0.0895      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.463      |
# |    explained_variance   | 0.857       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 37          |
# |    n_updates            | 2340        |
# |    policy_gradient_loss | -0.00182    |
# |    std                  | 0.375       |
# |    value_loss           | 39.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 531         |
# | time/                   |             |
# |    fps                  | 2135        |
# |    iterations           | 236         |
# |    time_elapsed         | 226         |
# |    total_timesteps      | 483328      |
# | train/                  |             |
# |    approx_kl            | 0.005519721 |
# |    clip_fraction        | 0.078       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.439      |
# |    explained_variance   | 0.846       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.3        |
# |    n_updates            | 2350        |
# |    policy_gradient_loss | 0.000169    |
# |    std                  | 0.375       |
# |    value_loss           | 41          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 534         |
# | time/                   |             |
# |    fps                  | 2135        |
# |    iterations           | 237         |
# |    time_elapsed         | 227         |
# |    total_timesteps      | 485376      |
# | train/                  |             |
# |    approx_kl            | 0.010335508 |
# |    clip_fraction        | 0.138       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.434      |
# |    explained_variance   | 0.785       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 22.2        |
# |    n_updates            | 2360        |
# |    policy_gradient_loss | 0.00237     |
# |    std                  | 0.373       |
# |    value_loss           | 42.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 540         |
# | time/                   |             |
# |    fps                  | 2135        |
# |    iterations           | 238         |
# |    time_elapsed         | 228         |
# |    total_timesteps      | 487424      |
# | train/                  |             |
# |    approx_kl            | 0.007441694 |
# |    clip_fraction        | 0.0916      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.435      |
# |    explained_variance   | 0.81        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.91        |
# |    n_updates            | 2370        |
# |    policy_gradient_loss | -2.03e-05   |
# |    std                  | 0.374       |
# |    value_loss           | 42.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 541         |
# | time/                   |             |
# |    fps                  | 2135        |
# |    iterations           | 239         |
# |    time_elapsed         | 229         |
# |    total_timesteps      | 489472      |
# | train/                  |             |
# |    approx_kl            | 0.005341992 |
# |    clip_fraction        | 0.0546      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.437      |
# |    explained_variance   | 0.833       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.4         |
# |    n_updates            | 2380        |
# |    policy_gradient_loss | 0.00105     |
# |    std                  | 0.375       |
# |    value_loss           | 46.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 546          |
# | time/                   |              |
# |    fps                  | 2135         |
# |    iterations           | 240          |
# |    time_elapsed         | 230          |
# |    total_timesteps      | 491520       |
# | train/                  |              |
# |    approx_kl            | 0.0062847575 |
# |    clip_fraction        | 0.0675       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.436       |
# |    explained_variance   | 0.825        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 17.5         |
# |    n_updates            | 2390         |
# |    policy_gradient_loss | -0.000826    |
# |    std                  | 0.374        |
# |    value_loss           | 49.8         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 548        |
# | time/                   |            |
# |    fps                  | 2135       |
# |    iterations           | 241        |
# |    time_elapsed         | 231        |
# |    total_timesteps      | 493568     |
# | train/                  |            |
# |    approx_kl            | 0.00706167 |
# |    clip_fraction        | 0.0715     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.434     |
# |    explained_variance   | 0.873      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.72       |
# |    n_updates            | 2400       |
# |    policy_gradient_loss | -0.00173   |
# |    std                  | 0.373      |
# |    value_loss           | 48.9       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 555          |
# | time/                   |              |
# |    fps                  | 2135         |
# |    iterations           | 242          |
# |    time_elapsed         | 232          |
# |    total_timesteps      | 495616       |
# | train/                  |              |
# |    approx_kl            | 0.0041063195 |
# |    clip_fraction        | 0.0405       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.433       |
# |    explained_variance   | 0.82         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.81         |
# |    n_updates            | 2410         |
# |    policy_gradient_loss | 0.000832     |
# |    std                  | 0.373        |
# |    value_loss           | 52.2         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 556          |
# | time/                   |              |
# |    fps                  | 2135         |
# |    iterations           | 243          |
# |    time_elapsed         | 233          |
# |    total_timesteps      | 497664       |
# | train/                  |              |
# |    approx_kl            | 0.0072777667 |
# |    clip_fraction        | 0.0658       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.437       |
# |    explained_variance   | 0.868        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 14.8         |
# |    n_updates            | 2420         |
# |    policy_gradient_loss | -0.000548    |
# |    std                  | 0.378        |
# |    value_loss           | 51.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 556          |
# | time/                   |              |
# |    fps                  | 2135         |
# |    iterations           | 244          |
# |    time_elapsed         | 234          |
# |    total_timesteps      | 499712       |
# | train/                  |              |
# |    approx_kl            | 0.0073875375 |
# |    clip_fraction        | 0.0923       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.447       |
# |    explained_variance   | 0.905        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 40.9         |
# |    n_updates            | 2430         |
# |    policy_gradient_loss | 0.000262     |
# |    std                  | 0.379        |
# |    value_loss           | 46           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 564         |
# | time/                   |             |
# |    fps                  | 2135        |
# |    iterations           | 245         |
# |    time_elapsed         | 234         |
# |    total_timesteps      | 501760      |
# | train/                  |             |
# |    approx_kl            | 0.007045859 |
# |    clip_fraction        | 0.0646      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.449      |
# |    explained_variance   | 0.847       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.78        |
# |    n_updates            | 2440        |
# |    policy_gradient_loss | -0.00154    |
# |    std                  | 0.378       |
# |    value_loss           | 39.7        |
# -----------------------------------------

# %%
# Test
env = DMControlWrapper("cartpole", "swingup")

# Test
test_episodes = 30
test_scores = []
test_rewards = []
start_time = time.time()


for e in range(test_episodes):
    state = env.reset()
    sum_rewards = 0

    for t in range(1000): # 1000 steps (half delta t of gym)
        action = PPO_model.predict(state)[0][0]
        state, reward, done, _ = env.step(action)
        
        
        sum_rewards += reward
    
    test_rewards.append(sum_rewards)


reward_average = mean(test_rewards)
reward_sigma = stdev(test_rewards)
end_time = time.time()
total_time = end_time - start_time
total_steps = sum(test_scores)
average_time_per_step = total_time / (test_episodes * 1000)

print()
print('Average time per step: {:.4f} seconds'.format(average_time_per_step))
print('Reward average: {:.2f}, Sigma: {:.2f}'.format(reward_average, reward_sigma))
# Out:
# Average time per step: 0.0003 seconds
# Reward average: 814.55, Sigma: 100.45

# %%
#create video
from moviepy.editor import ImageSequenceClip

def ppo_policy(time_step):
    timestep, reward, discount, observation = time_step
    state = np.concatenate((observation['position'],observation['velocity']))
    action = PPO_model.predict(state)[0][0]
    return action

# Load the cartpole environment
env = suite.load(domain_name='cartpole', task_name='swingup')

# Visualization and video creation
def save_video(policy):
    frames = []

    def policy_with_frame_grab(time_step):
        pixels = env.physics.render(height=480, width=640, camera_id=0)
        frames.append(pixels)
        return policy(time_step)

    # Create the viewer application
    viewer.launch(env, policy=policy_with_frame_grab)

    # Save the frames as a video
    clip = ImageSequenceClip(frames, fps=100)
    clip.write_videofile("video/PPO_dm_swingup.mp4", codec="libx264")

# Call the save_video function with your policy function
save_video(ppo_policy)
# Out:
# Moviepy - Building video video/PPO_dm_swingup.mp4.
# Moviepy - Writing video video/PPO_dm_swingup.mp4
# Moviepy - Done !
# Moviepy - video ready video/PPO_dm_swingup.mp4

# %% [markdown]
# ## SAC

# %%
env = DMControlWrapper("cartpole", "swingup")
SAC_model = SAC("MlpPolicy", env, verbose=1)
SAC_model.learn(total_timesteps=100000)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 43.7     |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 29       |
# |    time_elapsed    | 135      |
# |    total timesteps | 4000     |
# | train/             |          |
# |    actor_loss      | -7.2     |
# |    critic_loss     | 0.00805  |
# |    ent_coef        | 0.311    |
# |    ent_coef_loss   | -1.95    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 36.1     |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 31       |
# |    time_elapsed    | 257      |
# |    total timesteps | 8000     |
# | train/             |          |
# |    actor_loss      | -8.02    |
# |    critic_loss     | 0.00347  |
# |    ent_coef        | 0.0943   |
# |    ent_coef_loss   | -3.82    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 72.3     |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 31       |
# |    time_elapsed    | 383      |
# |    total timesteps | 12000    |
# | train/             |          |
# |    actor_loss      | -9.22    |
# |    critic_loss     | 0.0347   |
# |    ent_coef        | 0.0303   |
# |    ent_coef_loss   | -4.08    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 11899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 105      |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 32       |
# |    time_elapsed    | 486      |
# |    total timesteps | 16000    |
# | train/             |          |
# |    actor_loss      | -9.8     |
# |    critic_loss     | 0.0203   |
# |    ent_coef        | 0.0133   |
# |    ent_coef_loss   | -1.19    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 15899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 137      |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 34       |
# |    time_elapsed    | 581      |
# |    total timesteps | 20000    |
# | train/             |          |
# |    actor_loss      | -12.1    |
# |    critic_loss     | 0.164    |
# |    ent_coef        | 0.0113   |
# |    ent_coef_loss   | 1.42     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 19899    |
# ---------------------------------

# %%
# Test
env = DMControlWrapper("cartpole", "swingup")

# Test
test_episodes = 30
test_scores = []
test_rewards = []
start_time = time.time()


for e in range(test_episodes):
    state = env.reset()
    sum_rewards = 0

    for t in range(1000): # 1000 steps (half delta t of gym)
        action = PPO_model.predict(state)[0][0]
        state, reward, done, _ = env.step(action)
        
        
        sum_rewards += reward
    
    test_rewards.append(sum_rewards)


reward_average = mean(test_rewards)
reward_sigma = stdev(test_rewards)
end_time = time.time()
total_time = end_time - start_time
total_steps = sum(test_scores)
average_time_per_step = total_time / (test_episodes * 1000)


print()
print('Average time per step: {:.4f} seconds'.format(average_time_per_step))
print('Reward average: {:.2f}, Sigma: {:.2f}'.format(reward_average, reward_sigma))
# Out:
# Average time per step: 0.0002 seconds
# Reward average: 734.05, Sigma: 129.84

# %%
#create video
from moviepy.editor import ImageSequenceClip

def ppo_policy(time_step):
    timestep, reward, discount, observation = time_step
    state = np.concatenate((observation['position'],observation['velocity']))
    action = PPO_model.predict(state)[0][0]
    return action

# Load the cartpole environment
env = suite.load(domain_name='cartpole', task_name='swingup')

# Visualization and video creation
def save_video(policy):
    frames = []

    def policy_with_frame_grab(time_step):
        pixels = env.physics.render(height=480, width=640, camera_id=0)
        frames.append(pixels)
        return policy(time_step)

    # Create the viewer application
    viewer.launch(env, policy=policy_with_frame_grab)

    # Save the frames as a video
    clip = ImageSequenceClip(frames, fps=100)
    clip.write_videofile("video/SAC_dm_swingup.mp4", codec="libx264")

# Call the save_video function with your policy function
save_video(ppo_policy)
# Out:
# Moviepy - Building video video/SAC_dm_swingup.mp4.
# Moviepy - Writing video video/SAC_dm_swingup.mp4
# Moviepy - Done !
# Moviepy - video ready video/SAC_dm_swingup.mp4

# %%
# Access the model's attributes and methods
print("Policy network architecture:", PPO_model.policy)
print("Value function network architecture:", PPO_model.policy.value_net)
print("Optimizer:", PPO_model.policy.optimizer)

# You can get more detailed information about the policy by checking its attributes:
print("Policy network layers:", PPO_model.policy.mlp_extractor.policy_net)
print("Value function network layers:", PPO_model.policy.mlp_extractor.value_net)
# Out:
# Policy network architecture: ActorCriticPolicy(
#   (features_extractor): FlattenExtractor(
#     (flatten): Flatten(start_dim=1, end_dim=-1)
#   )
#   (mlp_extractor): MlpExtractor(
#     (shared_net): Sequential()
#     (policy_net): Sequential(
#       (0): Linear(in_features=5, out_features=64, bias=True)
#       (1): Tanh()
#       (2): Linear(in_features=64, out_features=64, bias=True)
#       (3): Tanh()
#     )
#     (value_net): Sequential(
#       (0): Linear(in_features=5, out_features=64, bias=True)
#       (1): Tanh()
#       (2): Linear(in_features=64, out_features=64, bias=True)
#       (3): Tanh()
#     )
#   )
#   (action_net): Linear(in_features=64, out_features=1, bias=True)
#   (value_net): Linear(in_features=64, out_features=1, bias=True)
# )
# Value function network architecture: Linear(in_features=64, out_features=1, bias=True)
# Optimizer: Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-05
#     foreach: None
#     fused: None
#     lr: 0.0003
#     maximize: False
#     weight_decay: 0
# )
# Policy network layers: Sequential(
#   (0): Linear(in_features=5, out_features=64, bias=True)
#   (1): Tanh()
#   (2): Linear(in_features=64, out_features=64, bias=True)
#   (3): Tanh()
# )
# Value function network layers: Sequential(
#   (0): Linear(in_features=5, out_features=64, bias=True)
#   (1): Tanh()
#   (2): Linear(in_features=64, out_features=64, bias=True)
#   (3): Tanh()
# )
